# %%
import pandas as pd
import numpy as np
import json
from tqdm.notebook import tqdm_notebook
import tmdbsimple as tmdb
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
basics = pd.read_csv('data/title_basics.csv.gz')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
merged =pd.read_csv('Data/Two_Years_tmdb_combined_data.csv.gz')
merged.tail()
# Out:
#         imdb_id  adult backdrop_path belongs_to_collection  budget  \
# 8693  tt7797670    0.0           NaN                   NaN     0.0
# 8694  tt7797790    0.0           NaN                   NaN     0.0
# 8695  tt8665056    0.0           NaN                   NaN     0.0
# 8696  tt8795764    0.0           NaN                   NaN     0.0
# 8697  tt9071078    0.0           NaN                   NaN     0.0
#
#                                genres  \
# 8693   [{'id': 27, 'name': 'Horror'}]
# 8694   [{'id': 27, 'name': 'Horror'}]
# 8695  [{'id': 37, 'name': 'Western'}]
# 8696   [{'id': 27, 'name': 'Horror'}]
# 8697   [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 8693                                                NaN  956214.0
# 8694                                                NaN  956219.0
# 8695  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 8696  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 8697    http://www.hkcinemagic.com/en/movie.asp?id=6627  201706.0
#
#      original_language                              original_title  ...  \
# 8693                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 8694                en         Edmund Kemper Part 3: La mort sévit  ...
# 8695                en                        Guns Along The Bravo  ...
# 8696                en                                   New Breed  ...
# 8697                cn                                        致命密函  ...
#
#      revenue  runtime                                   spoken_languages  \
# 8693     0.0     91.0                                                 []
# 8694     0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 8695     0.0     85.0                                                 []
# 8696     0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 8697     0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 8693  Released                                                NaN
# 8694  Released                                                NaN
# 8695  Released  Evil came to the Southwest until three blazing...
# 8696  Released                                                NaN
# 8697  Released                                                NaN
#
#                                            title  video  vote_average  \
# 8693  Edmund Kemper Part 2: La Mort C'est La Vie    0.0           0.0
# 8694         Edmund Kemper Part 3: La mort sévit    0.0           0.0
# 8695                        Guns Along The Bravo    0.0           0.0
# 8696                                   New Breed    0.0           0.0
# 8697                              Chinese Heroes    0.0           3.0
#
#      vote_count certification
# 8693        0.0           NaN
# 8694        0.0           NaN
# 8695        0.0           NaN
# 8696        0.0            NR
# 8697        2.0           NaN
#
# [5 rows x 26 columns]

# %%
financials = merged[['title', 'budget', 'revenue']]
financial_filter = financials.groupby(['budget', 'revenue'])
financials.head()
# Out:
#          title      budget      revenue
# 0          NaN         NaN          NaN
# 1  Tom & Jerry  50000000.0  132000000.0
# 2  Tom & Jerry  50000000.0  132000000.0
# 3  Tom & Jerry  50000000.0  132000000.0
# 4  Tom & Jerry  50000000.0  132000000.0

# %%
financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8698 entries, 0 to 8697
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    8696 non-null   object
#  1   budget   8696 non-null   float64
#  2   revenue  8696 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 204.0+ KB
