# %%
import pandas as pd
import numpy as np
import json
from tqdm.notebook import tqdm_notebook
import tmdbsimple as tmdb
import matplotlib.pyplot as plt

from scipy import stats
import scipy
scipy.__version__
# Out:
# '1.8.1'

# %%
import seaborn as sns
import plotly.express as px

# %%
df= pd.read_csv('Data/Two_Years_tmdb_combined_data.csv.gz')
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 2  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 3  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 4  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                            homepage        id original_language  \
# 0                               NaN       NaN               NaN
# 1  https://www.tomandjerrymovie.com  587807.0                en
# 2  https://www.tomandjerrymovie.com  587807.0                en
# 3  https://www.tomandjerrymovie.com  587807.0                en
# 4  https://www.tomandjerrymovie.com  587807.0                en
#
#   original_title  ...      revenue  runtime  \
# 0            NaN  ...          NaN      NaN
# 1    Tom & Jerry  ...  132000000.0    101.0
# 2    Tom & Jerry  ...  132000000.0    101.0
# 3    Tom & Jerry  ...  132000000.0    101.0
# 4    Tom & Jerry  ...  132000000.0    101.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                               tagline        title  video  vote_average  \
# 0                                 NaN          NaN    NaN           NaN
# 1  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
# 2  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
# 3  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
# 4  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
#
#   vote_count certification
# 0        NaN           NaN
# 1     2069.0            PG
# 2     2069.0            PG
# 3     2069.0            PG
# 4     2069.0            PG
#
# [5 rows x 26 columns]

# %%
ax = sns.barplot(data=df, x='certification', y='revenue', ci=68)

# %%
df['certification'].value_counts()
# Out:
# PG         6266
# R           451
# PG-13       180
# NR           66
# G            24
# NC-17         6
# Unrated       1
# -             1
# Name: certification, dtype: int64

# %%
needed_cols=['certification', 'revenue']
df[needed_cols]
# Out:
#      certification      revenue
# 0              NaN          NaN
# 1               PG  132000000.0
# 2               PG  132000000.0
# 3               PG  132000000.0
# 4               PG  132000000.0
# ...            ...          ...
# 8693           NaN          0.0
# 8694           NaN          0.0
# 8695           NaN          0.0
# 8696            NR          0.0
# 8697           NaN          0.0
#
# [8698 rows x 2 columns]

# %%
groups = {}
for certification in df['certification'].unique():
    temp=df.loc[df['certification']==certification, 'revenue']
    groups[certification]= temp
    
    
groups.keys()
# Out:
# dict_keys([nan, 'PG', 'R', 'G', 'NR', 'PG-13', 'NC-17', 'Unrated', '-'])

# %%
groups.items()
# Out:
# dict_items([(nan, Series([], Name: revenue, dtype: float64)), ('PG', 1       132000000.0
# 2       132000000.0
# 3       132000000.0
# 4       132000000.0
# 5       132000000.0
#            ...
# 8360            0.0
# 8387            0.0
# 8442            0.0
# 8493            0.0
# 8580            0.0
# Name: revenue, Length: 6266, dtype: float64), ('R', 3150         0.0
# 3151         0.0
# 3152         0.0
# 3156     14904.0
# 3161    105983.0
#           ...
# 8494         0.0
# 8528         0.0
# 8538         0.0
# 8563         0.0
# 8603         0.0
# Name: revenue, Length: 451, dtype: float64), ('G', 3158    224834564.0
# 3165    169327687.0
# 3169            0.0
# 3420     27965865.0
# 3528     19748009.0
# 3563            0.0
# 3591    183611771.0
# 3614    103291131.0
# 3710     45554533.0
# 3837     68411275.0
# 4077            0.0
# 4139            0.0
# 4307            0.0
# 7510    579707738.0
# 7536       100202.0
# 7809    165335153.0
# 7900            0.0
# 7995     44460850.0
# 8029     80936232.0
# 8097     18634654.0
# 8131            0.0
# 8375            0.0
# 8400            0.0
# 8650            0.0
# Name: revenue, dtype: float64), ('NR', 3160           0.0
# 3348    47386287.0
# 3427           0.0
# 3451           0.0
# 3537      268117.0
#            ...
# 8592           0.0
# 8596           0.0
# 8611           0.0
# 8681           0.0
# 8696           0.0
# Name: revenue, Length: 66, dtype: float64), ('PG-13', 3162    546388105.0
# 3163    296339527.0
# 3185            0.0
# 3186            0.0
# 3190    127666415.0
#            ...
# 8392      4035192.0
# 8444            0.0
# 8567            0.0
# 8652            0.0
# 8656            0.0
# Name: revenue, Length: 180, dtype: float64), ('NC-17', 3625    0.0
# 3737    0.0
# 4020    0.0
# 4216    0.0
# 8472    0.0
# 8499    0.0
# Name: revenue, dtype: float64), ('Unrated', 3628    0.0
# Name: revenue, dtype: float64), ('-', 8229    0.0
# Name: revenue, dtype: float64)])

# %% [markdown]
# ## The stakeholder's first question is: does the MPAA rating of a movie (G/PG/PG-13/R) affect how much revenue the movie generates?

# %% [markdown]
# 1A. (Null Hypothesis): a movies' Ratings doesn't affect the revenue it generates
#
# 1B. (Alternative Hypothesis): A movies' ratings can determine how much revenue a movie generates.

# %%
temp = np.abs(stats.zscore(groups['PG'])) > 3
temp.value_counts()
# Out:
# False    6208
# True       58
# Name: revenue, dtype: int64

# %%
#loop  through group dict
for certification,data in groups.items():
    #determine if there are any outliers
    outliers= np.abs(stats.zscore(data)) > 3
    ##Print a statement about how many outliers for which group name
    print(f'there were {outliers.sum()} outliers in the {certification} group')
    ##Remove the outliers from data and overwrite the sector data in the dict
    data = data.loc[~outliers]
    groups[certification] = data
# Out:
# there were 0 outliers in the nan group
# there were 58 outliers in the PG group
# there were 11 outliers in the R group
# there were 1 outliers in the G group
# there were 3 outliers in the NR group
# there were 5 outliers in the PG-13 group
# there were 0 outliers in the NC-17 group
# there were 0 outliers in the Unrated group
# there were 0 outliers in the - group

# %%
stats.normaltest(groups['PG']).pvalue
# Out:
# 0.0

# %%
stats.normaltest(groups['R']).pvalue<0.5
# Out:
# True

# %%
stats.normaltest(groups['PG-13']).pvalue<0.5
# Out:
# True

# %%
stats.normaltest(groups['G']).pvalue<0.5
# Out:
# True

# %%
ax = sns.barplot(data=df, x='certification', y='revenue', ci=68)

# %% [markdown]
# movies rated PG earned the most money in 2000 and 2001, thee P value is 0.0

# %%
df2= pd.read_csv('Data/final_tmdb_data_2002.csv.gz')
df2.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 2  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 3  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 4  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                            homepage        id original_language  \
# 0                               NaN       NaN               NaN
# 1  https://www.tomandjerrymovie.com  587807.0                en
# 2  https://www.tomandjerrymovie.com  587807.0                en
# 3  https://www.tomandjerrymovie.com  587807.0                en
# 4  https://www.tomandjerrymovie.com  587807.0                en
#
#   original_title  ...      revenue  runtime  \
# 0            NaN  ...          NaN      NaN
# 1    Tom & Jerry  ...  132000000.0    101.0
# 2    Tom & Jerry  ...  132000000.0    101.0
# 3    Tom & Jerry  ...  132000000.0    101.0
# 4    Tom & Jerry  ...  132000000.0    101.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                               tagline        title  video  vote_average  \
# 0                                 NaN          NaN    NaN           NaN
# 1  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
# 2  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
# 3  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
# 4  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.975
#
#   vote_count certification
# 0        NaN           NaN
# 1     2069.0            PG
# 2     2069.0            PG
# 3     2069.0            PG
# 4     2069.0            PG
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Do movies under 150 min in runtime affect revenue?

# %% [markdown]
# ## hypothesis for question 1
#
#  - Null hyp = a movie whos run time  exceeds 150 min does not affect movie revenue
#  reject null = a movie whos run time does not exceed 150 run time does affect a movies revenue

# %%
under_grp = df['runtime'] > 150
over_grp =  df ['runtime']< 150

# %%
df['under_rt'] = under_grp = df['runtime'] > 150

# %%
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 2  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 3  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
# 4  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                            homepage        id original_language  \
# 0                               NaN       NaN               NaN
# 1  https://www.tomandjerrymovie.com  587807.0                en
# 2  https://www.tomandjerrymovie.com  587807.0                en
# 3  https://www.tomandjerrymovie.com  587807.0                en
# 4  https://www.tomandjerrymovie.com  587807.0                en
#
#   original_title  ... runtime  \
# 0            NaN  ...     NaN
# 1    Tom & Jerry  ...   101.0
# 2    Tom & Jerry  ...   101.0
# 3    Tom & Jerry  ...   101.0
# 4    Tom & Jerry  ...   101.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                               tagline        title video  vote_average  \
# 0                                 NaN          NaN   NaN           NaN
# 1  Best of enemies. Worst of friends.  Tom & Jerry   0.0         6.975
# 2  Best of enemies. Worst of friends.  Tom & Jerry   0.0         6.975
# 3  Best of enemies. Worst of friends.  Tom & Jerry   0.0         6.975
# 4  Best of enemies. Worst of friends.  Tom & Jerry   0.0         6.975
#
#    vote_count certification under_rt
# 0         NaN           NaN    False
# 1      2069.0            PG    False
# 2      2069.0            PG    False
# 3      2069.0            PG    False
# 4      2069.0            PG    False
#
# [5 rows x 27 columns]

# %%
idx_outliers= np.abs(stats.zscore(under_grp)) >3
idx_outliers.sum()
# Out:
# 59

# %%
idx_outliers= np.abs(stats.zscore(over_grp)) >3
idx_outliers.sum()
# Out:
# 62

# %%
stats.normaltest(under_grp)
# Out:
# NormaltestResult(statistic=14753.196889174453, pvalue=0.0)

# %%
stats.normaltest(over_grp)
# Out:
# NormaltestResult(statistic=14554.778320063164, pvalue=0.0)

# %%
stats.levene(over_grp,under_grp)
# Out:
# LeveneResult(statistic=0.07489286052588508, pvalue=0.7843448655796872)

# %%
#run stats.ttest_ind on the 2 groups

stats.ttest_ind(over_grp,under_grp)
# Out:
# Ttest_indResult(statistic=782.4099498908379, pvalue=0.0)

# %% [markdown]
# The null hypothesis is rejected.  movies whos run time exceeds 150 minutes have a different revenue than those that do not in the years 2000 and 2001.

# %%
ax=sns.barplot(data=df, x = 'under_rt' ,y = 'revenue')

# %%
df_05 = pd.read_csv( 'Data/final_tmdb_data_2005.csv.gz')
df_05
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...         ...    ...                               ...
# 5878  tt6693930    0.0  /oWO8yKoCRdZGEDrdIOxLOszWcB0.jpg
# 5879  tt7069814    0.0                               NaN
# 5880  tt7616520    0.0                               NaN
# 5881  tt7775516    0.0                               NaN
# 5882  tt8294002    0.0  /6bWt2BxnMfqM3ei8T0qPp4IK706.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  50000000.0
# 2                      NaN  50000000.0
# 3                      NaN  50000000.0
# 4                      NaN  50000000.0
# ...                    ...         ...
# 5878                   NaN     10000.0
# 5879                   NaN         0.0
# 5880                   NaN         0.0
# 5881                   NaN         0.0
# 5882                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...                                                 ...
# 5878  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 5879                                                 []
# 5880                                                 []
# 5881  [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
# 5882                      [{'id': 18, 'name': 'Drama'}]
#
#                                          homepage        id original_language  \
# 0                                             NaN       NaN               NaN
# 1                https://www.tomandjerrymovie.com  587807.0                en
# 2                https://www.tomandjerrymovie.com  587807.0                en
# 3                https://www.tomandjerrymovie.com  587807.0                en
# 4                https://www.tomandjerrymovie.com  587807.0                en
# ...                                           ...       ...               ...
# 5878                                          NaN  550494.0                fa
# 5879                                          NaN  619708.0                nl
# 5880                                          NaN  792438.0                zh
# 5881  https://www.youtube.com/watch?v=wDeQ9CfW9YA  939616.0                en
# 5882                                          NaN  793159.0                en
#
#                 original_title  ...      revenue  runtime  \
# 0                          NaN  ...          NaN      NaN
# 1                  Tom & Jerry  ...  132000000.0    101.0
# 2                  Tom & Jerry  ...  132000000.0    101.0
# 3                  Tom & Jerry  ...  132000000.0    101.0
# 4                  Tom & Jerry  ...  132000000.0    101.0
# ...                        ...  ...          ...      ...
# 5878                      نقاب  ...     100000.0     90.0
# 5879     Kiddo the Super-Truck  ...          0.0      0.0
# 5880                    两个人的芭蕾  ...          0.0     93.0
# 5881  Everything Means Nothing  ...          0.0     70.0
# 5882              Pocket Angel  ...          0.0     82.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 5878  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
# 5879                                                 []  Released
# 5880                                                 []  Released
# 5881                                                 []  Released
# 5882  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1                    Best of enemies. Worst of friends.
# 2                    Best of enemies. Worst of friends.
# 3                    Best of enemies. Worst of friends.
# 4                    Best of enemies. Worst of friends.
# ...                                                 ...
# 5878                                                NaN
# 5879                                                NaN
# 5880                                                NaN
# 5881  A hostage situation of the mind. Does anyone c...
# 5882                                                NaN
#
#                          title  video  vote_average vote_count certification
# 0                          NaN    NaN           NaN        NaN           NaN
# 1                  Tom & Jerry    0.0         6.975     2069.0            PG
# 2                  Tom & Jerry    0.0         6.975     2069.0            PG
# 3                  Tom & Jerry    0.0         6.975     2069.0            PG
# 4                  Tom & Jerry    0.0         6.975     2069.0            PG
# ...                        ...    ...           ...        ...           ...
# 5878                      Mask    0.0         0.000        0.0           NaN
# 5879     Kiddo the Super-Truck    0.0         0.000        0.0           NaN
# 5880     Ballet of Two Dancers    0.0         0.000        0.0           NaN
# 5881  Everything Means Nothing    0.0        10.000        1.0           NaN
# 5882              Pocket Angel    0.0         0.000        0.0             G
#
# [5883 rows x 26 columns]

# %%
df.describe()
# Out:
#             adult        budget            id   popularity       revenue  \
# count  8696.00000  8.696000e+03  8.696000e+03  8696.000000  8.696000e+03
# mean      0.00069  3.719444e+07  4.683828e+05   109.718671  9.737467e+07
# std       0.02626  2.220779e+07  2.184452e+05    66.637652  6.157828e+07
# min       0.00000  0.000000e+00  1.600000e+01     0.600000  0.000000e+00
# 25%       0.00000  7.225000e+06  4.094735e+05     9.679500  1.854389e+06
# 50%       0.00000  5.000000e+07  5.878070e+05   151.699000  1.320000e+08
# 75%       0.00000  5.000000e+07  5.878070e+05   151.699000  1.320000e+08
# max       1.00000  1.400000e+08  1.006938e+06   264.951000  9.764756e+08
#
#            runtime        video  vote_average    vote_count
# count  8696.000000  8696.000000   8696.000000   8696.000000
# mean     98.507245     0.000460      6.277752   1550.808993
# std      16.748478     0.021443      1.727418   1053.231972
# min       0.000000     0.000000      0.000000      0.000000
# 25%     101.000000     0.000000      6.858750    227.750000
# 50%     101.000000     0.000000      6.975000   2069.000000
# 75%     101.000000     0.000000      6.975000   2069.000000
# max     345.000000     1.000000     10.000000  23187.000000

# %%
df20 = pd.read_csv('Data/final_tmdb_data_2020.csv.gz')
df20_df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df20 = pd.read_csv('Data/final_tmdb_data_2020.csv.gz')
#       2 df20_df.head()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
