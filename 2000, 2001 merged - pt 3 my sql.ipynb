# %%
import pandas as pd
import numpy as np
import json
from tqdm.notebook import tqdm_notebook
import tmdbsimple as tmdb
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

connection_str ="mysql+pymysql://root:DreAj2345@localhost/movies"

# %% [markdown]
# # Dataframes to create

# %%
basics = pd.read_csv('data/title_basics.csv.gz')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
title_basics = pd.read_csv('Data/title_basics.csv.gz')
title_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
title_ratings = pd.read_csv("Data/title_title.title.ratings.tsv.gz")
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.8       256
# 2  tt0000005            6.2      2519
# 3  tt0000006            5.1       173
# 4  tt0000007            5.4       783

# %%
merged =pd.read_csv('Data/Two_Years_tmdb_combined_data.csv.gz')
merged.tail()
# Out:
#         imdb_id  adult backdrop_path belongs_to_collection  budget  \
# 8693  tt7797670    0.0           NaN                   NaN     0.0
# 8694  tt7797790    0.0           NaN                   NaN     0.0
# 8695  tt8665056    0.0           NaN                   NaN     0.0
# 8696  tt8795764    0.0           NaN                   NaN     0.0
# 8697  tt9071078    0.0           NaN                   NaN     0.0
#
#                                genres  \
# 8693   [{'id': 27, 'name': 'Horror'}]
# 8694   [{'id': 27, 'name': 'Horror'}]
# 8695  [{'id': 37, 'name': 'Western'}]
# 8696   [{'id': 27, 'name': 'Horror'}]
# 8697   [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 8693                                                NaN  956214.0
# 8694                                                NaN  956219.0
# 8695  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# ...

# %%
title_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 82436  tt9914942     movie                             Life Without Sara Amat
# 82437  tt9915872     movie                               The Last White Witch
# 82438  tt9916170     movie                                      The Rehearsal
# 82439  tt9916190     movie                                          Safeguard
# 82440  tt9916362     movie                                              Coven
#
# ...

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 82439  tt9916190     movie                                          Safeguard
# 82439  tt9916190     movie                                          Safeguard
# 82439  tt9916190     movie                                          Safeguard
# 82440  tt9916362     movie                                              Coven
# 82440  tt9916362     movie                                              Coven
#
# ...

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
title_genres= exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_id_map)
title_genres = title_genres.drop(columns='genres_split')

# %%
genre = pd.DataFrame({"Genre_Name": genre_id_map.keys(),
                            'Genre_ID': genre_id_map.values()})

# %%
genre.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# # my sql

# %%
engine = create_engine(connection_str)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/movies)

# %%
if database_exists(connection_str) == False: create_database(connection_str)
else: print('The database already exists.')
# Out:
# The database already exists.

# %%
database_exists(connection_str)
# Out:
# True

# %%
title_basics.to_sql('title_basics', engine, if_exists = 'replace')
# Out:
# 82441

# %%
## Set the dataframe index and use index=True 
title_basics.set_index('int_index').to_sql('Title_basics',engine,index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 ## Set the dataframe index and use index=True
# ----> 2 title_basics.set_index('int_index').to_sql('Title_basics',engine,index=True)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
# ...

# %%
title_ratings.to_sql('title_ratings', engine, if_exists = 'replace')
# Out:
# 474878

# %%
genre.to_sql('genres', engine, if_exists = 'replace')
# Out:
# 26

# %%
merged.to_sql('tmdb_data', engine, if_exists = 'replace')
# Out:
# 8698

# %%
title_genres.to_sql('title_genres', engine, if_exists = 'replace')
# Out:
# 154076

# %%
q = """SELECT * FROM title_basics;"""
pd.read_sql(q, engine)
# Out:
#        index     tconst titleType  \
# 0          0  tt0035423     movie
# 1          1  tt0062336     movie
# 2          2  tt0069049     movie
# 3          3  tt0088751     movie
# 4          4  tt0096056     movie
# ...      ...        ...       ...
# 82436  82436  tt9914942     movie
# 82437  82437  tt9915872     movie
# 82438  82438  tt9916170     movie
# 82439  82439  tt9916190     movie
# 82440  82440  tt9916362     movie
#
#                                             primaryTitle  \
# 0                                         Kate & Leopold
# 1      The Tango of the Widower and Its Distorting Mi...
# 2                             The Other Side of the Wind
# 3                                      The Naked Monster
# 4                                   Crime and Punishment
# ...                                                  ...
# 82436                             Life Without Sara Amat
# 82437                               The Last White Witch
# ...

# %%
q = """SELECT * FROM title_ratings;"""
pd.read_sql(q, engine)
# Out:
#          index     tconst  averageRating  numVotes
# 0            0  tt0000001            5.7      1905
# 1            1  tt0000002            5.8       256
# 2            2  tt0000005            6.2      2519
# 3            3  tt0000006            5.1       173
# 4            4  tt0000007            5.4       783
# ...        ...        ...            ...       ...
# 474873  474873  tt9916204            8.1       242
# 474874  474874  tt9916348            8.5        17
# 474875  474875  tt9916362            6.4      4837
# 474876  474876  tt9916428            3.8        14
# 474877  474877  tt9916720            5.2       248
#
# [474878 rows x 4 columns]

# %%
q = """SELECT * FROM genres;"""
pd.read_sql(q, engine)
# Out:
#     index  Genre_Name  Genre_ID
# 0       0      Action         0
# 1       1       Adult         1
# 2       2   Adventure         2
# 3       3   Animation         3
# 4       4   Biography         4
# 5       5      Comedy         5
# 6       6       Crime         6
# 7       7       Drama         7
# 8       8      Family         8
# 9       9     Fantasy         9
# 10     10   Game-Show        10
# 11     11     History        11
# 12     12      Horror        12
# 13     13       Music        13
# 14     14     Musical        14
# 15     15     Mystery        15
# 16     16        News        16
# 17     17  Reality-TV        17
# 18     18     Romance        18
# 19     19      Sci-Fi        19
# 20     20       Short        20
# 21     21       Sport        21
# 22     22   Talk-Show        22
# 23     23    Thriller        23
# 24     24         War        24
# 25     25     Western        25

# %%
q = """SELECT * FROM title_genres;"""
pd.read_sql(q, engine)
# Out:
#         index     tconst  genre_id
# 0           0  tt0035423         5
# 1           0  tt0035423         9
# 2           0  tt0035423        18
# 3           1  tt0062336         7
# 4           2  tt0069049         7
# ...       ...        ...       ...
# 154071  82439  tt9916190         0
# 154072  82439  tt9916190         2
# 154073  82439  tt9916190        23
# 154074  82440  tt9916362         7
# 154075  82440  tt9916362        11
#
# [154076 rows x 3 columns]

# %%
q = """SELECT * FROM tmdb_data;"""
pd.read_sql(q, engine)
# Out:
#       index    imdb_id  adult                     backdrop_path  \
# 0         0          0    NaN                              None
# 1         1  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2         2  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3         3  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4         4  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...     ...        ...    ...                               ...
# 8693   8693  tt7797670    0.0                              None
# 8694   8694  tt7797790    0.0                              None
# 8695   8695  tt8665056    0.0                              None
# 8696   8696  tt8795764    0.0                              None
# 8697   8697  tt9071078    0.0                              None
#
#      belongs_to_collection      budget  \
# 0                     None         NaN
# 1                     None  50000000.0
# 2                     None  50000000.0
# ...
